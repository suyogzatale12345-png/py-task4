# %%
employee = {
    "emp_id": 1024,
    "first_name": "Sarah",
    "last_name": "Connor",
    "department": "Cyber Security",
    "role": "Lead Analyst",
    "salary": 95000,
    "hire_date": "2021-05-12",
    "office_location": "Austin",
    "remote_eligible": True,
    "manager_id": 501,
    "email": "s.connor@company.com",
    "phone": "555-0199",
    "laptop_id": "LP-772",
    "insurance_plan": "Premium",
    "vacation_days": 15
}

print(employee)
# Out:
# {'emp_id': 1024, 'first_name': 'Sarah', 'last_name': 'Connor', 'department': 'Cyber Security', 'role': 'Lead Analyst', 'salary': 95000, 'hire_date': '2021-05-12', 'office_location': 'Austin', 'remote_eligible': True, 'manager_id': 501, 'email': 's.connor@company.com', 'phone': '555-0199', 'laptop_id': 'LP-772', 'insurance_plan': 'Premium', 'vacation_days': 15}

# %%
print(f"employee = {employee}, len of employee = {len(employee)}, types of employee = {type(employee)}")
# Out:
# employee = {'emp_id': 1024, 'first_name': 'Sarah', 'last_name': 'Connor', 'department': 'Cyber Security', 'role': 'Lead Analyst', 'salary': 95000, 'hire_date': '2021-05-12', 'office_location': 'Austin', 'remote_eligible': True, 'manager_id': 501, 'email': 's.connor@company.com', 'phone': '555-0199', 'laptop_id': 'LP-772', 'insurance_plan': 'Premium', 'vacation_days': 15}, len of employee = 15, types of employee = <class 'dict'>

# %% [markdown]
# # popitem

# %%
a = employee.popitem()

print(a)
# Out:
# ('vacation_days', 15)

# %% [markdown]
# # values

# %%
a = employee.values()
employee["emp_id"]

print(a)
# Out:
# dict_values([1024, 'Sarah', 'Connor', 'Cyber Security', 'Lead Analyst', 95000, '2021-05-12', 'Austin', True, 501, 's.connor@company.com', '555-0199', 'LP-772', 'Premium'])

# %% [markdown]
# # fromkeys

# %%
d = ["ke","sd","fd","adcf",]
s = 0


f = dict.fromkeys(d,s)

print(f)
# Out:
# {'ke': 0, 'sd': 0, 'fd': 0, 'adcf': 0}

# %% [markdown]
# # copy

# %%
w = employee.copy()
print(w)
# Out:
# {'emp_id': 1024, 'first_name': 'Sarah', 'last_name': 'Connor', 'department': 'Cyber Security', 'role': 'Lead Analyst', 'salary': 95000, 'hire_date': '2021-05-12', 'office_location': 'Austin', 'remote_eligible': True, 'manager_id': 501, 'email': 's.connor@company.com', 'phone': '555-0199', 'laptop_id': 'LP-772', 'insurance_plan': 'Premium'}
