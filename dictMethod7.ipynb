# %%
watch = {
    "brand": "apple",
    "model": "series 9",
    "price": 399,
    "sensorse": ["hear rate","ECG","Sp02","GPS"],
    "battery": {
        "capacity": "308mAh",
        "life": "18h",
        "charging": "fast",
    },
    "water_resistant": "true"
}

print(watch)
# Out:
# {'brand': 'apple', 'model': 'series 9', 'price': 399, 'sensorse': ['hear rate', 'ECG', 'Sp02', 'GPS'], 'battery': {'capacity': '308mAh', 'life': '18h', 'charging': 'fast'}, 'water_resistant': 'true'}

# %%
print(f"watch = {watch}, len of smart watch = {len(watch)}, types of smart watch = {type(watch)}")
# Out:
# watch = {'brand': 'apple', 'model': 'series 9', 'price': 399, 'sensorse': ['hear rate', 'ECG', 'Sp02', 'GPS'], 'battery': {'capacity': '308mAh', 'life': '18h', 'charging': 'fast'}, 'water_resistant': 'true'}, len of smart watch = 6, types of smart watch = <class 'dict'>

# %% [markdown]
# # setdefault method

# %%
a =  watch.setdefault("available", "true")

print(a)
# Out:
# true

# %%
print(watch)
# Out:
# {'brand': 'apple', 'model': 'series 9', 'price': 399, 'sensorse': ['hear rate', 'ECG', 'Sp02', 'GPS'], 'battery': {'capacity': '308mAh', 'life': '18h', 'charging': 'fast'}, 'water_resistant': 'true'}

# %% [markdown]
# #  pop Mehtod

# %%
watch.pop("available")

print(watch)
# Out:
# {'brand': 'apple', 'model': 'series 9', 'price': 399, 'sensorse': ['hear rate', 'ECG', 'Sp02', 'GPS'], 'battery': {'capacity': '308mAh', 'life': '18h', 'charging': 'fast'}, 'water_resistant': 'true'}

# %% [markdown]
# # popitem

# %%
watch.popitem()

print(watch)
# Out:
# {'brand': 'apple', 'model': 'series 9', 'price': 399, 'sensorse': ['hear rate', 'ECG', 'Sp02', 'GPS'], 'battery': {'capacity': '308mAh', 'life': '18h', 'charging': 'fast'}}
