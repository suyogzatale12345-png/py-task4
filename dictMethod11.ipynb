# %%
nagpur = {
    "station_id": "VANP",
    "city": "Nagpur",
    "temp_celsius": 36.0,
    "humidity_pct": 13,
    "wind_speed_mph": 7,
    "wind_direction": "SW",
    "condition": "Partly Sunny",
    "high_temp": 37,
    "low_temp": 23,
    "last_updated": "2026-03-17 16:30"
}

print(nagpur)
# Out:
# {'station_id': 'VANP', 'city': 'Nagpur', 'temp_celsius': 36.0, 'humidity_pct': 13, 'wind_speed_mph': 7, 'wind_direction': 'SW', 'condition': 'Partly Sunny', 'high_temp': 37, 'low_temp': 23, 'last_updated': '2026-03-17 16:30'}

# %% [markdown]
# # Copy

# %%
nagpurDupli = nagpur.copy()

print(nagpurDupli)
# Out:
# {'station_id': 'VANP', 'city': 'Nagpur', 'temp_celsius': 36.0, 'humidity_pct': 13, 'wind_speed_mph': 7, 'wind_direction': 'SW', 'condition': 'Partly Sunny', 'high_temp': 37, 'low_temp': 23, 'last_updated': '2026-03-17 16:30'}

# %% [markdown]
# # setdefault

# %%
a = nagpur.setdefault("place","bardi")
print(a)
# Out:
# bardi

# %% [markdown]
# # update

# %%
nagpur.update({"high_temp": "52"})

print(nagpur)
# Out:
# {'station_id': 'VANP', 'city': 'Nagpur', 'temp_celsius': 36.0, 'humidity_pct': 13, 'wind_speed_mph': 7, 'wind_direction': 'SW', 'condition': 'Partly Sunny', 'high_temp': '52', 'low_temp': 23, 'last_updated': '2026-03-17 16:30', 'place': 'bardi'}

# %% [markdown]
# # get

# %%
q = nagpur.get("last_updated")

print(q)
# Out:
# 2026-03-17 16:30
