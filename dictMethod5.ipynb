# %%
app = {
    "name": "instagram",
    "version": 280.1,
    "devloper": "meta",
    "size_mb": 154,
    "is_free": "true"
}

print(app)
# Out:
# {'name': 'instagram', 'version': 280.1, 'devloper': 'meta', 'size_mb': 154, 'is_free': 'true'}

# %%
print(f"app = {app}, len of mobile app = {len(app)}, types of mobile app = {type(app)}")
# Out:
# app = {'name': 'instagram', 'version': 280.1, 'devloper': 'meta', 'size_mb': 154, 'is_free': 'true'}, len of mobile app = 5, types of mobile app = <class 'dict'>

# %% [markdown]
# # fromkeys Method

# %%
a = ('k1', 'k2', 'k3')
b = 0

td = dict.fromkeys(a, b)

print(td)
# Out:
# {'k1': 0, 'k2': 0, 'k3': 0}

# %% [markdown]
# # copy method

# %%
mobile_app = app.copy()

print(mobile_app)
# Out:
# {'name': 'instagram', 'version': 280.1, 'devloper': 'meta', 'size_mb': 154, 'is_free': 'true'}

# %% [markdown]
# # clear Method

# %%
mobile_app.clear()

print(mobile_app)
# Out:
# {}
