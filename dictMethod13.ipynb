# %%
product = {
    "product_info": {
        "id": "SKU-9921",
        "name": "Mechanical Keyboard",
        "brand": "Logitech",
        "category": "Peripherals",
        "made_in": "Taiwan"
    },
    "technical_specs": {
        "switch_type": "Cherry MX Blue",
        "backlight": "RGB",
        "connectivity": {
            "wireless": True,
            "battery_life": "40 hours"
        }
    },
    "commerce": {
        "price": 149.99,
        "currency": "USD",
        "stock_count": 45,
        "warranty_months": 24
    },
    "customer_metrics": {
        "rating": 4.8,
        "review_count": 1250
    }
}




print(product)
# Out:
# {'product_info': {'id': 'SKU-9921', 'name': 'Mechanical Keyboard', 'brand': 'Logitech', 'category': 'Peripherals', 'made_in': 'Taiwan'}, 'technical_specs': {'switch_type': 'Cherry MX Blue', 'backlight': 'RGB', 'connectivity': {'wireless': True, 'battery_life': '40 hours'}}, 'commerce': {'price': 149.99, 'currency': 'USD', 'stock_count': 45, 'warranty_months': 24}, 'customer_metrics': {'rating': 4.8, 'review_count': 1250}}

# %%
print(f"product = {product} len of product = {len(product)}, types of product {type(product)}")
# Out:
# product = {'product_info': {'id': 'SKU-9921', 'name': 'Mechanical Keyboard', 'brand': 'Logitech', 'category': 'Peripherals', 'made_in': 'Taiwan'}, 'technical_specs': {'switch_type': 'Cherry MX Blue', 'backlight': 'RGB', 'connectivity': {'wireless': True, 'battery_life': '40 hours'}}, 'commerce': {'price': 149.99, 'currency': 'USD', 'stock_count': 45, 'warranty_months': 24}, 'customer_metrics': {'rating': 4.8, 'review_count': 1250}} len of product = 4, types of product <class 'dict'>

# %% [markdown]
# # copy

# %%
p2 = product.copy()

print(p2)
# Out:
# {'product_info': {'id': 'SKU-9921', 'name': 'Mechanical Keyboard', 'brand': 'Logitech', 'category': 'Peripherals', 'made_in': 'Taiwan'}, 'technical_specs': {'switch_type': 'Cherry MX Blue', 'backlight': 'RGB', 'connectivity': {'wireless': True, 'battery_life': '40 hours'}}, 'commerce': {'price': 149.99, 'currency': 'USD', 'stock_count': 45, 'warranty_months': 24}, 'customer_metrics': {'rating': 4.8, 'review_count': 1250}}

# %% [markdown]
# # clear

# %%
p2.clear()
print(p2)
# Out:
# {}

# %% [markdown]
# # get

# %%
p2 = product.get("product_info")

print(p2)
# Out:
# {'id': 'SKU-9921', 'name': 'Mechanical Keyboard', 'brand': 'Logitech', 'category': 'Peripherals', 'made_in': 'Taiwan'}

# %% [markdown]
# # keys

# %%
l2 = product.keys()

print(l2)
# Out:
# dict_keys(['product_info', 'technical_specs', 'commerce', 'customer_metrics'])
