# %%
transction ={
    "trans_id": "TXN889",
    "Type": "Withdrawal",
    "amount": 500,
    "tags": ["ATM","Traval","Cash","Urgent"],
    "bank_info": {
        "branch": "main St",
        "code": 101,
        "auth": "verified"
    },
    "currency": "USD",
    "Success": True
}

print(transction)
# Out:
# {'trans_id': 'TXN889', 'Type': 'Withdrawal', 'amount': 500, 'tags': ['ATM', 'Traval', 'Cash', 'Urgent'], 'bank_info': {'branch': 'main St', 'code': 101, 'auth': 'verified'}, 'currency': 'USD', 'Success': True}

# %% [markdown]
# # copy Method

# %%
f1 = transction.copy()

print(f1)
# Out:
# {'trans_id': 'TXN889', 'Type': 'Withdrawal', 'amount': 500, 'tags': ['ATM', 'Traval', 'Cash', 'Urgent'], 'bank_info': {'branch': 'main St', 'code': 101, 'auth': 'verified'}, 'currency': 'USD', 'Success': True}

# %% [markdown]
# # clear method

# %%
f1.clear()


print(f1)
# Out:
# {}

# %% [markdown]
# # popitem

# %%
transction.popitem()

print(transction)
# Out:
# {'trans_id': 'TXN889', 'Type': 'Withdrawal', 'amount': 500, 'tags': ['ATM', 'Traval', 'Cash', 'Urgent'], 'bank_info': {'branch': 'main St', 'code': 101, 'auth': 'verified'}, 'currency': 'USD'}

# %% [markdown]
# # keys method

# %%
d = transction.keys()

print(d)
# Out:
# dict_keys(['trans_id', 'Type', 'amount', 'tags', 'bank_info', 'currency'])

# %% [markdown]
# # values method

# %%
s = transction.values()

print(s)
# Out:
# dict_values(['TXN889', 'Withdrawal', 500, ['ATM', 'Traval', 'Cash', 'Urgent'], {'branch': 'main St', 'code': 101, 'auth': 'verified'}, 'USD'])
