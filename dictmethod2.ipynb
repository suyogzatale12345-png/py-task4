# %%
car_info = {
    "brand": "Ford",
    "model": "Mustang",
    "Year": 1964,
    "color": {"Red","Black","white"},
    "engine": "v8"
}

print(car_info)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'Year': 1964, 'color': {'white', 'Red', 'Black'}, 'engine': 'v8'}

# %% [markdown]
# # keys

# %%
x = car_info.keys()

car_info["stock"] = 10


print(x)
# Out:
# dict_keys(['brand', 'model', 'Year', 'color', 'engine', 'stock'])

# %%
print(car_info)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'Year': 1964, 'color': {'white', 'Red', 'Black'}, 'engine': 'v8', 'stock': 10}

# %%
print(car_info)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'Year': 1964, 'color': {'white', 'Red', 'Black'}, 'engine': 'v8'}

# %% [markdown]
# # pop

# %%
a = car_info.pop("stock")

print(a)
# Out:
# 10

# %% [markdown]
# # popiteam

# %%
b = car_info.popitem()

print(b)
# Out:
# ('engine', 'v8')
