# %%
course = {
    "title": "python",
    "id": 5,
    "duration": 10,
    "level": "Easy",
    "cert": "true"
}


print(course)


print()
print()


print(f"course = {course}, len of course = {len(course)}, types of course = {type(course)}")
# Out:
# {'title': 'python', 'id': 5, 'duration': 10, 'level': 'Easy', 'cert': 'true'}
#
#
# course = {'title': 'python', 'id': 5, 'duration': 10, 'level': 'Easy', 'cert': 'true'}, len of course = 5, types of course = <class 'dict'>

# %% [markdown]
# # Get

# %%
x = course.get("level")

print(x)
# Out:
# Easy

# %% [markdown]
# # update

# %%
course.update({"year": 2026})


print(course)
# Out:
# {'title': 'python', 'id': 5, 'duration': 10, 'level': 'Easy', 'cert': 'true', 'year': 2026}

# %% [markdown]
# # values

# %%
d = course.values()

course["id "] = 15

print(d)
# Out:
# dict_values(['python', 5, 10, 'Easy', 'true', 2026, 15])
